# %%
import spacy
from spacy import displacy
from spacy.tokens import Doc, Token
from spacy.tokenizer import Tokenizer
from spacy.matcher import Matcher, PhraseMatcher
from collections import defaultdict, Counter

import numpy as np
import pandas as pd
import sys

# imports required for BabelNet API calls
import urllib2
import urllib
import json
import gzip

from StringIO import StringIO

# other imports
import os

# %%
# load statistical model
#nlp = spacy.load('en')
nlp = spacy.load('en_core_web_lg')

# %%
# Create Whitespace tokenizer which will be use d 
class WhitespaceTokenizer(object):
    def __init__(self, vocab, ):
        self.vocab = vocab
    
    def __call__(self, text):
        words = text.split(' ')
        spaces = [True] * len(words)
        return Doc(self.vocab, words=words, spaces = spaces)

# %%
# use Whitespace tokenizer if my text has already been tokenized
nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

doc = nlp(" ".join(word_list))
for token in doc:
    print token.text, token.lemma_, token.pos_, token.head, token.dep_
    
# this line restores the tokeniser back to the spaCy default
nlp.tokenizer = nlp.Defaults.create_tokenizer(nlp)

# %%
# if the full pipeline is executed, we can get several details about 
# each token
for token in doc3:
    print token.i, token.idx, token.text, token.lemma_, token.pos_, token.head, token.dep_

# once a document is parsed, named entities can be returned by:
print u"\nPrinting entities"

for ents in doc3.ents:    
    print ents.text, ents.label_, ents.start, ents.end, ents.lower_

# similarly, noun phrases can be emitted by:
print u"\nPrinting noun chunks"

for ents in doc3.noun_chunks:    
    print ents.text, ents.label_, ents.start, ents.end

# %%
# we will create a custom pipeline component which will capture
# 2 and 3 token entity and concept terms, merge the spans and 
# tag each token with is_entity or is_concept custom tag

class NGramMerger(object):
    def __init__(self, nlp, **patterns):
        # register custom token extension
        if not (Token.has_extension('is_concept')):            
            Token.set_extension('is_concept', default =False)
        
        if not (Token.has_extension('is_entity')):
            Token.set_extension('is_entity', default=False)        
        
        # create two matchers: one for bigram and another for trigrams
        self.matcher_bi  = PhraseMatcher(nlp.vocab)            
        self.matcher_tri = PhraseMatcher(nlp.vocab)    
        # patterns are passed as dictionary objects with the key
        # conforming to a template: entity|concept 2|3
        for p in patterns:                
            nlp_patterns = [nlp(text) for text in patterns[p]]            
            assert p.endswith("2") or p.endswith("3")        
            if p.endswith("2"):
                self.matcher_bi.add(p, None, *nlp_patterns)
            else:
                self.matcher_tri.add(p, None, *nlp_patterns)  
    
    def __call__(self, doc):
        matchers = [self.matcher_tri, self.matcher_bi]
        entity_spans = []
        concept_spans = []
        # run matchers in order, tri-gram first
        for m in matchers:
            matches = m(doc)
            for match_id, start, end in matches:
                span = doc[start:end]    
                if nlp.vocab.strings[match_id].startswith("entity"):
                    entity_spans.append(span)
                else:
                    concept_spans.append(span)
            
            for span in entity_spans:
                span.merge()
                for t in span:
                    t._.is_entity = True
            
            for span in concept_spans:
                span.merge()
                for t in span:
                    t._.is_concept = True
            
            concept_spans = []
            entity_spans = []
        return doc

# %%
# patterns will actually come from gold standard datasets
# entity_3
p1 = [u'Robert De Niro', u"John Fitzgerald Kennedy"]
# entity_2
p2 = [u'De Niro', u'Adolf Hitler']
# concept_3
p3 = [u'executive vice president', u'8 mm film']
# concept_2
p4 = [u'vice president', u'Vice president']

nlp = spacy.load('en')
ngram_merger = NGramMerger(nlp, entity3=p1, entity2=p2, concept3=p3, concept2=bi_gram_terms)
nlp.add_pipe(ngram_merger, last=True)
for pipe_id, _ in nlp.pipeline:
    print pipe_id
# Out:
# tagger
# parser
# ner
# NGramMerger

# %%
#input_str = u"Al Pacino and Robert De Niro starred together in The Godfather Part II. " +\
 #            "De Niro and executive vice president Robert Evans disagreed on aspects of the film. "+\
  #           "Disagreeing is one thing but apples are another."

input_str = u'The Albanian mafia have been responsible for heroin trafficking in Italy.'

print input_str
doc = nlp(input_str)

print u"\nPrinting entities"

for ents in doc.ents:    
    print ents.text, ents.label_, ents.start, ents.end, ents.lower_
# Out:
# The Albanian mafia have been responsible for heroin trafficking in Italy.
#
# Printing entities
# Albanian NORP 1 2 albanian
# Italy GPE 10 11 italy

# %%
def process_token(t, doc):
    state = dict(count=0)
    def _process_token(t):
        string = None
        if t.ent_type_ not in ['DATE', 'TIME', 'PERCENT', 'ORDINAL', 'CARDINAL'] and t.ent_iob_ == 'B': # if start of named entity                            
            string = doc.ents[state['count']].text.replace(" ", "_")
            state['count'] += 1            
        # if inside named entity or punctuation or space, ignore token
        elif ((t.ent_iob_ == 'I' and t.ent_type_ not in ['DATE', 'TIME', 'PERCENT', 'ORDINAL', 'CARDINAL']) or t.pos_ in ['PUNCT', 'SPACE']):
            pass
        # if entity: retain case, create single token
        elif t._.is_entity: 
            string = t.text.replace(" ","_") 
        # if concept: lower case, create single token
        elif t._.is_concept:
            string = t.text.lower().replace(" ","_") 
        # if uni-gram, grab lemma
        else:
            string = t.lemma_
        
        return string
    return _process_token

# %%
pt = process_token(None, doc)
string_list = []
for sent in doc.sents:
    string_list.append(filter(None, map(pt, sent)))

print string_list
# Out:
# [[u'the', u'Albanian', u'mafia', u'have', u'be', u'responsible', u'for', u'heroin', u'trafficking', u'in', u'Italy']]

# %%
# let's build the phrase lists

vocab = pd.read_csv("1A.english.vocabulary.txt", header=None, delimiter="\t", names=['term'], keep_default_na=False)
train = pd.read_csv("1A.english.training.data.txt", header=None, delimiter="\t", names=['term', 'term_type'])
test = pd.read_csv("1A.english.test.data.txt", header=None, delimiter="\t", names=['term', 'term_type'])
trial = pd.read_csv("1A.english.trial.data.txt", header=None, delimiter="\t", names=['term', 'term_type'])

# %%
# confirm size of training data
[df.shape[0] for df in vocab, train, test, trial]
# Out:
# [218753, 1500, 1500, 50]

# %%
# find token count of vocab terms
ser = vocab.term.str.split().str.len()
if 'term_count' not in vocab.columns:
    vocab['term_count'] = ser

bi_gram_terms = list(vocab.query('term_count == 2').term)
# convert to unicode for loading as Patterns in spaCy
bi_gram_terms = [unicode(s, "utf-8") for s in bi_gram_terms]

tri_gram_terms = list(vocab.query('term_count == 3').term)
tri_gram_terms = [unicode(s, "utf-8") for s in tri_gram_terms]

print len(bi_gram_terms)
print len(tri_gram_terms)
print len(bi_gram_terms) + len(tri_gram_terms)
# Out:
# 51622
# 6651
# 58273

# %%
# append training, test and trial data to a single dataframe
full_list = train.append(test).append(trial)
# reset index
full_list = full_list.reset_index(drop=True)

# split full_list between 2 and 3-term concepts and entities
term_count = full_list.term.str.split().str.len()
# add series to dataframe - we now have term count as well
# if it doesn't exist already
if 'term_count' not in full_list.columns:
    full_list['term_count'] = term_count

full_list.head()

# split 
bi_gram_concepts = full_list.query('term_type == \'Concept\' & term_count == 2')
tri_gram_concepts = full_list.query('term_type == \'Concept\' & term_count == 3')

bi_gram_entities = full_list.query('term_type == \'Entity\' & term_count == 2')
tri_gram_entities = full_list.query('term_type == \'Entity\' & term_count == 3')

# %%
# print length of train/test/trial data split by entity/concept and token count
print [len(l) for l in bi_gram_concepts, tri_gram_concepts, bi_gram_entities, tri_gram_entities]
# Out:
# [305, 19, 509, 114]

# %%
# get trigram terms from vocab.
# entities and concepts are mixed
# i need to know the case to capture them
# by lower-casing everything i lose surface form detail
# therefore, will lose sense as well
bi_gram_entities
# Out:
#                         term term_type  term_count
# 14             Carly Fiorina    Entity           2
# 18              Erna Brodber    Entity           2
# 19                Raoul Dufy    Entity           2
# 22                Skara Brae    Entity           2
# 23                Murder One    Entity           2
# 24            Emmett Tyrrell    Entity           2
# 28             Sachs Harbour    Entity           2
# 36               A1 motorway    Entity           2
# 51            North Carolina    Entity           2
# 53                Forest Way    Entity           2
# 60             Younger Dryas    Entity           2
# 65               New Zealand    Entity           2
# 67             Belfast Lough    Entity           2
# 71             Sajid Mahmood    Entity           2
# 78              Eric Becklin    Entity           2
# 80             Bevis Hillier    Entity           2
# 87            Cyclone Gafilo    Entity           2
# 103                  El Nino    Entity           2
# 116             Leslie Caron    Entity           2
# 125               Carlo Levi    Entity           2
# 127           Richard Posner    Entity           2
# 137               Jon Cassar    Entity           2
# 146                True Life    Entity           2
# 148           Patrizia Ciofi    Entity           2
# 153              White House    Entity           2
# 154           Sandy Mitchell    Entity           2
# 156          Preston Manning    Entity           2
# 161             Martin Brest    Entity           2
# 164              Brady Smith    Entity           2
# 167                True Grit    Entity           2
# ...                      ...       ...         ...
# 2886            Frank Harris    Entity           2
# 2896           Joseph Stalin    Entity           2
# 2897            Jimmy Tingle    Entity           2
# 2898           Ivete Sangalo    Entity           2
# 2906            Carlos Tosca    Entity           2
# 2907        Grigori Perelman    Entity           2
# 2911             Fort Sumter    Entity           2
# 2921            Fourth World    Entity           2
# 2929              Judd Gregg    Entity           2
# 2940         Altai Mountains    Entity           2
# 2941          Typhoon Saomai    Entity           2
# 2949     European Parliament    Entity           2
# 2960             Saadia Gaon    Entity           2
# 2961              Jon Clardy    Entity           2
# 2970            Tupelo Press    Entity           2
# 2971           Bradgate Park    Entity           2
# 2972       Michael Castleman    Entity           2
# 2974          Samuel Johnson    Entity           2
# 2981               Bob Broeg    Entity           2
# 2984              Niels Bohr    Entity           2
# 2989        Giovanni Bellini    Entity           2
# 2998             Tommy Gavin    Entity           2
# 3002             Burger King    Entity           2
# 3006               Tim Tebow    Entity           2
# 3019      Emmeline Pankhurst    Entity           2
# 3024  Konstantin Tsiolkovsky    Entity           2
# 3027         Hurricane Iniki    Entity           2
# 3029            Don McKellar    Entity           2
# 3035          Cromford Canal    Entity           2
# 3049          Matthew Murphy    Entity           2
#
# [509 rows x 3 columns]

# %%
from nltk.corpus import wordnet as wn

bi_dict = {term:len(wn.synsets(term.replace(" ", "_"))) for term in bi_gram_terms}
tri_dict = {term:len(wn.synsets(term.replace(" ", "_"))) for term in tri_gram_terms}
#wn.synsets("the_simpsons")[0].lemma_names()
#.lemma_names()

# %%
# some Wordnet sysnet stats

from collections import Counter
bi_match_counter = Counter(bi_dict.values())
tri_match_counter = Counter(tri_dict.values())

#[key for key, value in bi_dict.iteritems() if value == 19]
#[syn.lemma_names() for syn in wn.synsets("break_up")]

print sum([v for k, v in bi_match_counter.iteritems() if k>0])
print sum([v for k, v in tri_match_counter.iteritems() if k>0])
print bi_match_counter[0]
print tri_match_counter[0]
# Out:
# 29205
# 2460
# 22417
# 4191

# %%
# get list of bi-gram and tri-gram terms which were not found
# in WordNet
bi_wn_notfound = [k for k, v in bi_dict.iteritems() if v == 0]

tri_wn_notfound = [k for k, v in tri_dict.iteritems() if v == 0]

# there are 446 court cases with a specific surface form X+ v. X+
# these are assumed to be named entities; we don't need to look these
# up in BabelNet
tri_wn_notfound = filter(lambda x: x.split()[1] != 'v.', tri_wn_notfound)

# %%
potential_entities = {}
alternate_case = {}

# find potential entities among bi_gram terms
for term in bi_gram_terms:
    synsets = wn.synsets(term.replace(" ", "_"))    
    found_lemma = False
    for syn in synsets:        
        for lemma in syn.lemma_names():            
            lemma = lemma.replace("_", " ")                                    
            if lemma.lower() == term and reduce(lambda x, y: x.istitle() & y.istitle(), lemma.split()):
                potential_entities[term] = lemma
                found_lemma = True
                break
            elif lemma.lower() == term and reduce(lambda x, y: x.istitle() | y.istitle(), lemma.split()):
                alternate_case[term] = lemma
        if found_lemma:
            break

# %%
# find potential entities among tri-gram terms
# find number of cases        
sum(map(lambda x: 1 if x.split()[1]=='v.' else 0, tri_gram_terms))
# cases can be automatically added to the tri_gram_terms
for term in tri_gram_terms:
    tokens = term.split()
    if tokens[1]== 'v.':
        potential_entities[term] = "%s v. %s" % (tokens[0].title(), tokens[2].title())

# %%
# find potential entities among tri-grams
for term in tri_gram_terms:
    synsets = wn.synsets(term.replace(" ", "_"))    
    found_lemma = False
    for syn in synsets:        
        for lemma in syn.lemma_names():            
            lemma = lemma.replace("_", " ")            
            if lemma.lower() == term and reduce(lambda x, y: x.istitle() & y.istitle(), lemma.split()[0::2]):
                potential_entities[term] = lemma
                #print term, '-', lemma
                found_lemma = True
                break
            elif lemma.lower() == term and reduce(lambda x, y: x.istitle() | y if type(y)==bool else y.istitle(), lemma.split()):
                alternate_case[term] = lemma
        if found_lemma:
            break

# %%
# Now we'll write some code to lookup lexicalisations in BabelNet
# using the provided API
class BabelSense():
    #lemma = 'the simpsons'
    lang = 'EN'
    targetLang = 'EN'
    #_key  = 'e906d134-a25f-47ac-8596-2bb4a9cc16cf'
    pos = 'NOUN'
    source = 'WIKI'
    
    def __init__(self, key='e906d134-a25f-47ac-8596-2bb4a9cc16cf'):
        self.params = {            
            'searchLang' : lang,
            'targetLang' : targetLang,
            'key'  : key,
            'pos'  : pos,
            'source' : source
        }
        
        self.service_url = 'https://babelnet.io/v5/getSenses'
    
    def __call__(self, lemma):        
        self.params['lemma'] = lemma.encode('utf-8')
        url = self.service_url + '?' + urllib.urlencode(self.params)
        request = urllib2.Request(url)
        request.add_header('Accept-encoding', 'gzip')
        response = urllib2.urlopen(request)
        
        if response.info().get('Content-Encoding') == 'gzip':
            buf = StringIO( response.read())
            f = gzip.GzipFile(fileobj=buf)
            data = json.loads(f.read())
            results = [result for result in data]
            # retrieving BabelSense data
            if len(results) > 0:
                simpleLemmas =  [result['properties']['simpleLemma'] for result in data]
                return list(set(simpleLemmas))
                #return list(set([sl.encode('utf-8') for sl in simpleLemma]))
            else:
                return []

# %%
# test look for 50 random examples from bi_terms
babel_results = {}
ran = [np.random.randint(len(tri_wn_notfound)) for _ in range(50)]
tests = [tri_wn_notfound[x] for x in ran]

def get_sense_from_BabelNet(searchList):
    babel = BabelSense()
    babel_results = {}
    for idx, t in enumerate(searchList):
        try:
            if ((idx+1) % 500 == 0):
                print "Done %d" % (idx+1)
            babel_results[t] = babel(t)
        except:
            print idx
            print sys.exc_info()[0]
    return babel_results

babel_results = get_sense_from_BabelNet(tri_wn_notfound)
# Out:
# Done 500
# Done 1000
# Done 1500
# Done 2000
# Done 2500
# Done 3000
# Done 3500

# %%
for k, v in babel_results.iteritems():
    for lemma in v:
        lemma = lemma.replace("_", " ")
        
        if ((lemma.lower() == k) and reduce(lambda x,y: x.istitle() & y.istitle(), lemma.split()[0::2])):
            print lemma
            break
# Out:
# Mountain Time Zone
# De la Cruz
# Theory of Art
# Ex parte Bollman
# Tropical Storm Arlene
# Battle of Cannae
# R v Brown
# Socialisme ou Barbarie
# Agusan del Sur
# Wooden Roller Coaster
# Code of Ethics
# A New Life
# Nevus of Ota
# Axiom of Choice
# First Person Shooter
# Tropical Storm Claudette
# Piazza del Popolo
# Heart of Stone
# Cold Dark Matter
# Boulevard des Capucines
# Happy New Year
# Torre del Greco
# Ministry of Labor
# Puerta del Sol
# Shock and Awe
# Strength of Materials
# The Very Reverend
# Koigi wa Wamwere
# Jornal do Brasil
# Van den Berg
# Structural Equation Modeling
# Near Eastern Archaeology
# Monetary Policy Committee
# Torre del Mangia
# Sociology of Religion
# Past Is Prologue
# St. Nicholas Church
# Rock Paper Scissors
# Freedom from Fear
# Carrier Air Wing
# History of Psychology
# Ministry of Defense
# Orion Publishing Group
# Juan del Castillo
# Potato virus Y
# Life Goes On
# Paul et Virginie
# Salar del Huasco
# Lusa News Agency
# Tropical Storm Alpha
# Barra do Corda
# Eduardo Dos Santos
# Call to Arms
# Laurentide Ice Sheet
# Religion of Humanity
# Maderas del Carmen
# Gruffydd ap Llywelyn
# Sack of Rome
# Hot Air Balloon
# Pierre et Jean
# Florida State Seminoles
# Power Macintosh G3
# New World Order
# History of Science
# The Biggest Loser
# Ministry of Transport
# Bassano del Grappa
# Boys v Chaplin
# Surigao del Sur
# Pontes e Lacerda
# Court of Appeal
# Little League Baseball
# Isla del Sol
# Polish Air Force
# Disruptive Technology Office
# Principles of Economics
# Government Accountability Office
# Beguines and Beghards
# The Eleventh Hour
# Central do Brasil
# Millennium Prize Problems
# Ministry of Communications
# Basilio do Nascimento
# Seven Deadly Sins
# Federal Administrative Court
# San Francisco Fog
# Marathon des Sables
# Garde du Corps
# Van der Kolk
# In the Money
# Cat Scratch Fever
# Romeo y Julieta
# Pierrot le Fou
# Right to Die
# Town Planning Board
# My Best Friend
# Khalid bin Mahfouz
# Pay It Forward
# Show of Hands
# Dafydd ap Gruffydd
# General Land Office
# Red vs. Blue
# Van der Vorst
# Eine kleine Nachtmusik
# Orfeo ed Euridice
# Alien vs. Predator
# Torre del Oro
# Salt and Pepper
# House of Stuart
# Round and Round
# Judith and Holofernes
# Ordem dos Engenheiros
# Zell am See
# Thurn und Taxis
# Tropical Storm Tammy
# Bergen op Zoom
# Von der Heydt
# Ex parte Young
# Pittsburgh compound B
# Faculty of Arts
# Little Brown Jug
# Riva del Garda
# The Last One
# Punta del Este
# First Aid Kit
# Eastern Catholic Churches
# Ex parte Quirin
# Saad bin Laden
# Krak des Chevaliers
# War of Aggression
# Home Field Advantage
# Electronic Toll Collection
# Battle of Franklin
# Philosophy of Science
# Jack of Spades
# Mega Man X
# Take a Picture
# History of Religions
# The Vanishing American
# Hegemony or Survival
# Supply and Demand
# Abraham ibn Ezra
# Tipping the Velvet
# Eppur Si Muove
# Siege of Jerusalem
# Jablonec nad Nisou
# Sogn og Fjordane
# Strategic Defense Initiative
# Coeur d'Alene Press
# Ancient Olympic Games
# The Four Horsemen
# Eastern Time Zone
# Angel of Death
# Ministry of Construction
# Ahmad ibn Tulun
# Museo del Prado
# Amrozi bin Nurhasyim
# Pay to Play
# Copa del Rey
# Paradise and Hell
# Emperor of Japan
# Tropical Storm Chris
# Minister of Tourism
# Yin and Yang
# Iglesia ni Cristo
# Scottish Labour Party
# Board of Trade
# Sea of Dreams
# Teatro degli Arcimboldi
# Flotsam and Jetsam
# Boulevard des Italiens
# Below the Line
# Seven of Spades
# Alice in Wonderland
# The Highway Code
# Girl Next Door
# John Q. Public
# Det norske Theater
# Coteau des Prairies
# Fear of Flying
# Loggia dei Lanzi
# All Saints Church
# Kansas City Blues
# Camera dei Deputati
# Tristan und Isolde
# Page v Smith
# Gare du Nord
# Sacco and Vanzetti
# Tropical Storm Emily
# The Burning Bush
# Canadian Heraldic Authority
# Council of Florence
# Santiago del Estero
# Bully for Brontosaurus
# Playa del Sol
# Day of Wrath
# Tropical Storm Gert
# Bertrand du Guesclin
# In re Winship
# Concha y Toro
# Sein und Zeit
# Ahmad ibn Hanbal
# Counties of England
# Theoretical Computer Science
# Universidad del Salvador
# Pound for Pound
# Scottish Parliament Building
# Accademia dei Lincei
# The Country Wife
# Piazza del Plebiscito
# Smash and Grab
# A Christmas Carol
# The Oregon Trail
# Ministry of Interior
# Kingdom of Italy
# Jardin du Luxembourg
# French New Wave
# This is True
# Hide and Seek
# Tug of War
# Little Black Dress
# Torri del Benaco
# Ciudad del Carmen
# Native American Day
# Key Lime Pie
# Bras d'Or Lake
# Air Traffic Controller
# Badge of Honor
# Mistakes Were Made
# Shades of Gray
# Speed of Sound
# Agusan del Norte
# University of Valle
# National Health Insurance
# Hasta la Vista
# Swiss Bank Corporation
# Interstate Highway System
# Additional Member System
# Mutt and Jeff
# Nacht und Nebel
# History of Technology
# Red Letter Day
# Tropical Storm Dean
# Pont du Gard
# Northeastern State University
# Connect the Dots
# Andrea del Sarto
# David and Goliath
# Dichtung und Wahrheit
# Parc des Princes
# Battle of Towton
# Nevado del Ruiz
# Fountain of Time
# Madonna with Child
# Departments of France
# The Scarlet Letter
# Flat Earth Society
# Monoamine oxidase A
# Ministry of Trade
# Flora of Australia
# Bahr el Ghazal
# Theory of Everything
# Brut y Tywysogion
# Missing in Action
# Local Service District
# At the Drive-In
# Banco do Nordeste
# Jewish Palestinian Aramaic
# Gruffudd ap Cynan
# Cathleen ni Houlihan
# Roses Are Red
# Business Is Business
# National Technological University
# Petition of Right
# Bobos in Paradise
# Van der Woude
# In re Gault
# Shoot 'Em Up
# The Selfish Giant
# Protein kinase A
# Protein kinase B
# Protein kinase C
# Gissing v Gissing
# Haus der Kunst
# The Bog People
# Witch of Agnesi
# Three of Hearts
# Dominus ac Redemptor
# National Constituent Assembly
# Supermassive Black Hole
# King of Clubs
# Reductio ad Hitlerum
# Moses und Aron
# The Invisible Man
# Tropical Storm Barry
# Tropical Storm Harvey
# The F Word
# Mabo v Queensland
# Freddy vs. Jason
# Al-Waleed bin Talal
# Portage la Prairie
# Tropical Storm Bonnie
# Muhammad bin Saud
# Australian Rules Football
# Zamboanga del Sur
# State of Mexico
# Military Reserve Force
# Darfur is Dying
# House of Romanov
# Office du Niger
# Pointe du Hoc
# Corpus Juris Civilis
# Van der Vlist
# Return to Sender
# Surfactant protein B
# Cirque du Soleil
# Battle of Oriskany
# Tropical Storm Delta
# Vila do Conde
# Foras na Gaeilge
# Hotel du Lac
# West Coast Jazz
# National Scenic Area
# Santee Sioux Reservation
# Lazarus of Bethany
# Perceval le Gallois
# Central Business District
# Erythroplasia of Queyrat
# Life Is Good
# Castell y Bere
# Hollywood vs. America
# All Souls Church
# Plaza del Sol
# National Botanic Gardens
# Bachelor of Architecture
# Capture the Flag
# Jornada del Muerto
# Ford Model T
# Madonna and Child
# The Three Graces
# Spot the Difference
# Kinetic Monte Carlo
# Van den Bergh
# Japanese battleship Yamato
# Annalen der Physik
# Colonia del Sacramento
# Division by Zero
# Bread and Circuses
# Jardin des Plantes
# Director of Bands
# Concerto for Orchestra
# Chemin des Dames
# Foz do Iguaçu
# Marion duPont Scott
# Search and Rescue
# Central Time Zone
# Minister of Defence
# Jumping the Shark
# Open Door Policy
# Lions Clubs International
# Water of Life
# Melena del Sur
# Grand Theft Auto
# Fat and Thin
# Leave to Remain
# Judgment of Paris
# Rest in Peace
# Hunayn ibn Ishaq
# Great Red Spot
# Tropical Storm Hanna
# Anan ben David
# Hierve el Agua
# Welt am Sonntag
# Accademia del Cimento
# Adam and Eve
# The Great Adventure
# Piazza del Campo
# Ciudad del Este
# Supply Chain Management
# Way Down East
# Meall nan Tarmachan
# Surfactant protein C
# Command and Control
# Lost and Found
# Beat 'Em Up
# Director of Communications
# Confederate States Army
# Ascension of Jesus
# Pont des Arts
# East Africa Protectorate
# Van der Walt
# Tropical Storm Debby
# Adult High School
# Military Police Corps
# Queen of Heaven
# Cividale del Friuli
# Tropical Storm Bill
# Books of Chronicles
# Weil am Rhein
# Solomon ibn Gabirol
# Piazza dei Miracoli
# Yang di-Pertuan Agong
# Faisal bin Fahd
# Abd al-Karim Qasim
# Davao del Sur
# Fences and Windows
# Set and Setting
# Palisades Interstate Parkway
# Rylands v Fletcher
# Institute of Technology
# Jacob ben Asher
# Crime of Passion
# Noli Me Tangere
# À la Carte
# Santillana del Mar
# Mountain Meadows Massacre
# Khalid bin Sultan
# Jack of Hearts
# Gruffydd ap Rhys
# Mit brennender Sorge
# Ministry of Works
# Miller v Miller
# Tree of Life
# Ex parte Garland
# Dafydd ap Gwilym
# Bridge to Nowhere
# History of Photography
# Queen of Clubs
# Hippolyte et Aricie
# Unit of Measure
# Coming of Age
# Auf der Maur
# Sense and Sensibility
# Rancho del Cielo
# The Tribute Money
# Davao del Norte
# Minister of Defense
# Place des Vosges
# Window of Opportunity
# Zamboanga del Norte
# Queen of Hearts
# Second French Empire
# Strategic Environmental Assessment
# Wijk aan Zee
# Sodom and Gomorrah
# Miracle on Ice
# Madonna del Parto
# Postal Regulatory Commission
# Temple Beth Israel
# Elections in Afghanistan
# Sisterhood Is Powerful
# Freedom of Information
# Optical Character Recognition
# Van der Voort
# University of Birmingham
# Moment of Silence
# Rinconete y Cortadillo
# American Quarter Horse
# School of Education
# Gregorio del Pilar
# Home for Christmas
# R v Collins
# Venus and Adonis
# Break a Leg
# Maximum Residue Limit
# Cruzeiro do Sul
# Accademia degli Incamminati
# Tiempos del Mundo
# Air Traffic Control
# Law and Order
# Kilroy Was Here
# Bastien und Bastienne
# The Black Arrow
# Tropical Storm Franklin
# Paseo del Prado
# Man vs. Machine
# Madog ap Maredudd
# L'Anse aux Meadows
# Canal du Midi
# Off Our Backs
# Joachim du Bellay
# Jack of Clubs
# Said bin Taimur
# Lac qui Parle
# Cowboy del Amor
# The Valley Library
# Llywelyn ap Gruffudd
# Donoghue v Stevenson
# Department of Labour
# Nick du Toit
# Faculty of Law
# Forte dei Marmi
# Apollo and Daphne
# Bidean nam Bian
# Urban Enterprise Zone
# Usman dan Fodio
# Shades of Green
# Federal Aviation Administration
# Tropical Storm Beryl
# National Heritage Site
# Banco do Brasil
# Santiago de Compostela
# Spy vs. Spy
# House of Bourbon
# Serra do Mar
# Jardim do Mar
# Territory of Papua
# Tropical Storm Zeta
# In re Quinlan
# Fauna of Australia
# Ospedale degli Innocenti
# Siamese Fighting Fish
# Lamb of God
# All That Remains
# Egmond aan Zee
# Princeton University Chapel
# Apollo Lunar Module
# Henry du Pont
# Ice Cream Truck
# Rhys ap Thomas
# King of Hearts
# Van der Ryn
# Medina del Campo
# Intertropical Convergence Zone
# Rhys ap Tewdwr
# Estrela do Sul
# Athanasius of Alexandria
# Bingu wa Mutharika
# The Lonely Man
# Oberkommando der Wehrmacht
# Droste zu Vischering
# Mar del Plata
# Ex parte Bain
# Riva degli Schiavoni
# Daniel arap Moi
# Doing It Right
# Armenian Apostolic Church
# The Enemy Within
# Before the Storm
# Air Force Blue
# Salem bin Laden
# Liberal Front Party
# Tropical Storm Matthew
# Lanao del Sur
# Debits and Credits
# Corrie ten Boom
# The Salvation Army
# Swimming With Dolphins
# Rue du Bac
# Pros vs. Joes
# Habana del Este
# Angra dos Reis
# Israel Defense Forces
# Butte des Morts
# Now or Never
# Extremely Large Telescope
# Via del Corso
# Raid on Deerfield
# King of Spades
# Sitz im Leben
# Flora of China
# Place des Arts
# Aiguille du Midi
# History of Biology
# Pacific Time Zone
# Minister of Agriculture
# Fire Dynamics Simulator
# Near Death Experience
# Trans-Alaska Pipeline System
# Vale of Tears
# Minister of Justice
# Maredudd ab Owain
# Hotel du Vin
# The Flower Girl
# Minister of Health
# Ministry of Justice
# The Big Picture
# Abide with Me
# Notre Dame School
# Piazza delle Erbe
# Bild am Sonntag
# West End Theatre
# Head and Shoulders
# Member of Congress
# Sweet and Sour
# Elections in Argentina
# Van den Bos
# Eames Lounge Chair
# National Armed Forces
# German submarine U-505
# Ariadne auf Naxos
# Bachelor of Engineering
# European Monetary System
# Festival du Voyageur
# Five O'Clock Shadow
# Shades of Blue
# I Need Love
# Banco del Libro
# North Magnetic Pole
# Declaration of War
# Follow the Money
# Van der Hart
# Mergers and Acquisitions
# Place du Tertre
# Cuban Missile Crisis
# Trial by Combat
# Fond du Lac
# North Atlantic Oscillation
# Death by Hanging
# Rhys ap Gruffydd
# Central South University
# Mutually Assured Destruction
# Scottish Episcopal Church
# William ap Thomas
# Apples and Oranges
# National Security Service
# Council of State
# Mann Gulch Fire
# Jan du Preez
# On Your Toes
# Pieces of Me
# Ex parte Milligan
# Digital Signal Processing
# Freiburg im Breisgau
# Tropical Storm Henri
# Ministry of Defence
# The Philadelphia Experiment
# The Bartered Bride
# Antiquities Advisory Board
# Ministry of Housing
# Chemical Vapor Deposition
# The Last Night
# Six Nations Championship
# Pay and Display
# Sol y Sombra
# Ali Abu Al-Ragheb
# Stella Maris College
# Pentalogy of Cantrell
# Klondike Gold Rush
# Sierra del Carmen
# Confession of Faith
# Australian Army Reserve
# Death Before Dishonor
# Tropical Storm Erika
# Nakhon Si Thammarat
# Duke Blue Devils
# Public Service Announcement
# House of Habsburg
# Flesh and Blood
# Ribera del Duero
# Saint Ignatius Church
# Love of Life
# Smoke and Mirrors
# Moscow Art Theatre
# Sierra del Rosario
# Name that Tune
# Madog ap Llywelyn
# Battle of Evesham
# Book of Hours

# %%
import pickle
# pickle the results because it took us a long time to query BabelNet
# plus technically, we normally only get 1,000 coins a day

dest = os.path.join('pickle')
if not os.path.exists(dest):
    os.mkdir(dest)
    
#pickle.dump(babel_results, 
#            open(os.path.join(dest,'bi_babel_results.pkl'), 'wb'),
#            protocol=2
#           )

pickle.dump(babel_results, 
            open(os.path.join(dest,'tri_babel_results.pkl'), 'wb'),
            protocol=2
           )

# %%
# add new potential entities mined from BabelNet
for term, res  in babel_results.iteritems():
    for lemma in res:
        lemma = lemma.replace("_", " ")        
        if (lemma.lower() == term) and \
            reduce(lambda x, y: x.istitle() & y.istitle(), lemma.split()):
            potential_entities[term] = lemma
            break

# %%
# so far we have 1,550 potential entities (without babel search)
print len(potential_entities)

# ..to 3070 with babel search
potential_entities
# Out:
# 3070
# {u'mixed nuts': u'Mixed Nuts',
#  u'government printing office': u'Government Printing Office',
#  u'shark attack': u'Shark Attack',
#  u'rabbit island': u'Rabbit Island',
#  u'crown colony': u'Crown Colony',
#  u'slavic muslims': u'Slavic Muslims',
#  u'holy joe': u'Holy Joe',
#  u'alaska native': u'Alaska Native',
#  u'dail eireann': u'Dail Eireann',
#  u'full court': u'Full Court',
#  u'commissioner v. sunnen': u'Commissioner v. Sunnen',
#  u'born again': u'Born Again',
#  u'northern alliance': u'Northern Alliance',
#  u'forced marriage': u'Forced Marriage',
#  u'paul v. virginia': u'Paul v. Virginia',
#  u'opening act': u'Opening Act',
#  u'air corps': u'Air Corps',
#  u'model town': u'Model Town',
#  u'st. jerome': u'St. Jerome',
#  u'speed metal': u'Speed Metal',
#  u'weight loss': u'Weight Loss',
#  u'liquid courage': u'Liquid Courage',
#  u'fermi paradox': u'Fermi Paradox',
#  u'department of education': u'Department of Education',
#  u'braided river': u'Braided River',
#  u'speiser v. randall': u'Speiser v. Randall',
#  u'memorial day': u'Memorial Day',
#  u'state law': u'State Law',
#  u'secretary of war': u'Secretary of War',
#  u'democratic party': u'Democratic Party',
#  u'indian literature': u'Indian Literature',
#  u'light rail': u'Light Rail',
#  u'sun bear': u'Sun Bear',
#  u'green party': u'Green Party',
#  u'cave painting': u'Cave Painting',
#  u'bosnia and herzegovina': u'Bosnia and Herzegovina',
#  u'old turkic': u'Old Turkic',
#  u'merchant navy': u'Merchant Navy',
#  u'congo basin': u'Congo Basin',
#  u'house of hanover': u'House of Hanover',
#  u'angelica archangelica': u'Angelica Archangelica',
#  u'green park': u'Green Park',
#  u'arizona v. california': u'Arizona v. California',
#  u'independence movement': u'Independence Movement',
#  u'tropical storm': u'Tropical Storm',
#  u'oxford english': u'Oxford English',
#  u'blank slate': u'Blank Slate',
#  u'permanent secretary': u'Permanent Secretary',
#  u'norwich school': u'Norwich School',
#  u'free world': u'Free World',
#  u'citizenship day': u'Citizenship Day',
#  u'weather report': u'Weather Report',
#  u'london underground': u'London Underground',
#  u'tin pan alley': u'Tin Pan Alley',
#  u'the beast': u'The Beast',
#  u'to love': u'To Love',
#  u'latin percussion': u'Latin Percussion',
#  u'lost city': u'Lost City',
#  u'edelman v. jordan': u'Edelman v. Jordan',
#  u'saint joseph': u'Saint Joseph',
#  u'present indicative': u'Present Indicative',
#  u'tooth brushing': u'Tooth Brushing',
#  u'computational geometry': u'Computational Geometry',
#  u'king rat': u'King Rat',
#  u'court martial': u'Court Martial',
#  u'central thai': u'Central Thai',
#  u'european central bank': u'European Central Bank',
#  u'augustinian canons': u'Augustinian Canons',
#  u'video clip': u'Video Clip',
#  u'maine coon': u'Maine Coon',
#  u'american pie': u'American Pie',
#  u'immaculate conception': u'Immaculate Conception',
#  u'god game': u'God Game',
#  u'blood oath': u'Blood Oath',
#  u'kaoru ishikawa': u'Kaoru Ishikawa',
#  u'escobedo v. illinois': u'Escobedo v. Illinois',
#  u'federal security bureau': u'Federal Security Bureau',
#  u'road safety': u'Road Safety',
#  u'town square': u'Town Square',
#  u'gregg v. georgia': u'Gregg v. Georgia',
#  u'indian camp': u'Indian Camp',
#  u'lions club': u'Lions Club',
#  u'inter-services intelligence': u'Inter-Services Intelligence',
#  u'yom kippur': u'Yom Kippur',
#  u'feist v. rural': u'Feist v. Rural',
#  u'osborne v. ohio': u'Osborne v. Ohio',
#  u'mapp v. ohio': u'Mapp v. Ohio',
#  u'norman french': u'Norman French',
#  u'the pilot': u'The Pilot',
#  u'pragati maidan': u'Pragati Maidan',
#  u'fearful symmetry': u'Fearful Symmetry',
#  u'summer lightning': u'Summer Lightning',
#  u'best value': u'Best Value',
#  u'black eagle': u'Black Eagle',
#  u'old greek': u'Old Greek',
#  u'roman legion': u'Roman Legion',
#  u'master of education': u'Master of Education',
#  u'graham v. connor': u'Graham v. Connor',
#  u'orthodox judaism': u'Orthodox Judaism',
#  u'old saxon': u'Old Saxon',
#  u'war department': u'War Department',
#  u'middle irish': u'Middle Irish',
#  u'liu li': u'Liu Li',
#  u'midnight blue': u'Midnight Blue',
#  u'open source': u'Open Source',
#  u'beauharnais v. illinois': u'Beauharnais v. Illinois',
#  u'air national guard': u'Air National Guard',
#  u'bronze age': u'Bronze Age',
#  u'swift v. tyson': u'Swift v. Tyson',
#  u'all saints': u'All Saints',
#  u'risk management': u'Risk Management',
#  u'richard roe': u'Richard Roe',
#  u'eagle scout': u'Eagle Scout',
#  u'pacific standard time': u'Pacific Standard Time',
#  u'section eight': u'Section Eight',
#  u'breard v. greene': u'Breard v. Greene',
#  u'hollow point': u'Hollow Point',
#  u'meinhard v. salmon': u'Meinhard v. Salmon',
#  u'rasul v. bush': u'Rasul v. Bush',
#  u'power cut': u'Power Cut',
#  u'jazz guitar': u'Jazz Guitar',
#  u'blue bayou': u'Blue Bayou',
#  u'operation sundevil': u'Operation Sundevil',
#  u'business day': u'Business Day',
#  u'color theory': u'Color Theory',
#  u'arctic tern': u'Arctic Tern',
#  u'cort v. ash': u'Cort v. Ash',
#  u'physics education': u'Physics Education',
#  u'time regained': u'Time Regained',
#  u'urban geography': u'Urban Geography',
#  u'buckley v. valeo': u'Buckley v. Valeo',
#  u'drug enforcement agency': u'Drug Enforcement Agency',
#  u'new englander': u'New Englander',
#  u'costa rican': u'Costa Rican',
#  u'jewish new year': u'Jewish New Year',
#  u'ring v. arizona': u'Ring v. Arizona',
#  u'east germanic': u'East Germanic',
#  u'base exchange': u'Base Exchange',
#  u'bonfire night': u'Bonfire Night',
#  u'wilkerson v. utah': u'Wilkerson v. Utah',
#  u'ku kluxer': u'Ku Kluxer',
#  u'eastern christianity': u'Eastern Christianity',
#  u'round table': u'Round Table',
#  u'liu hong': u'Liu Hong',
#  u'bush v. vera': u'Bush v. Vera',
#  u'schmerber v. california': u'Schmerber v. California',
#  u'black maria': u'Black Maria',
#  u'new delhi': u'New Delhi',
#  u'universal v. reimerdes': u'Universal v. Reimerdes',
#  u'roman church': u'Roman Church',
#  u'the labyrinth': u'The Labyrinth',
#  u'bad faith': u'Bad Faith',
#  u'keiichi inamine': u'Keiichi Inamine',
#  u'master of divinity': u'Master of Divinity',
#  u'house of representatives': u'House of Representatives',
#  u'chief executive': u'Chief Executive',
#  u'highway code': u'Highway Code',
#  u'u. s. army': u'U. S. Army',
#  u'zero sum': u'Zero Sum',
#  u'comptroller general': u'Comptroller General',
#  u'ice house': u'Ice House',
#  u'non serviam': u'Non Serviam',
#  u'scottish gaelic': u'Scottish Gaelic',
#  u'golden horde': u'Golden Horde',
#  u'orange blossom': u'Orange Blossom',
#  u'black tai': u'Black Tai',
#  u'defense secretary': u'Defense Secretary',
#  u'arch bridge': u'Arch Bridge',
#  u'mountain time': u'Mountain Time',
#  u'blood diamond': u'Blood Diamond',
#  u'rashtriya swayamsevak sangh': u'Rashtriya Swayamsevak Sangh',
#  u'billroth i': u'Billroth I',
#  u'u.s. congress': u'U.S. Congress',
#  u'ghost cat': u'Ghost Cat',
#  u'single father': u'Single Father',
#  u'gilmore girls': u'Gilmore Girls',
#  u'blues harp': u'Blues Harp',
#  u'zablocki v. redhail': u'Zablocki v. Redhail',
#  u'social justice': u'Social Justice',
#  u'group selection': u'Group Selection',
#  u'chinese pagoda': u'Chinese Pagoda',
#  u'holy sacrament': u'Holy Sacrament',
#  u'band aid': u'Band Aid',
#  u'black muslim': u'Black Muslim',
#  u'western christianity': u'Western Christianity',
#  u'arm wrestling': u'Arm Wrestling',
#  u'tuatha de': u'Tuatha De',
#  u'liu chong': u'Liu Chong',
#  u'health economics': u'Health Economics',
#  u'mckune v. lile': u'Mckune v. Lile',
#  u'protestant reformation': u'Protestant Reformation',
#  u'doggy style': u'Doggy Style',
#  u'old lace': u'Old Lace',
#  u'arena football': u'Arena Football',
#  u'enemy combatant': u'Enemy Combatant',
#  u'plyler v. doe': u'Plyler v. Doe',
#  u'flag day': u'Flag Day',
#  u'shopping trolley': u'Shopping Trolley',
#  u'investigative journalism': u'Investigative Journalism',
#  u'powell v. texas': u'Powell v. Texas',
#  u'knight templar': u'Knight Templar',
#  u'the treasury': u'The Treasury',
#  u'greek orthodox church': u'Greek Orthodox Church',
#  u'abstract expressionism': u'Abstract Expressionism',
#  u'payne v. tennessee': u'Payne v. Tennessee',
#  u'hoyt v. florida': u'Hoyt v. Florida',
#  u'corner store': u'Corner Store',
#  u'continental congress': u'Continental Congress',
#  u'ottoman turk': u'Ottoman Turk',
#  u'memphis tigers': u'Memphis Tigers',
#  u'gunpowder plot': u'Gunpowder Plot',
#  u'central powers': u'Central Powers',
#  u'monster truck': u'Monster Truck',
#  u'holy order': u'Holy Order',
#  u'environmental law': u'Environmental Law',
#  u'red eye': u'Red Eye',
#  u'ali baba': u'Ali Baba',
#  u'teague v. lane': u'Teague v. Lane',
#  u'furman v. georgia': u'Furman v. Georgia',
#  u'ghost train': u'Ghost Train',
#  u'spike island': u'Spike Island',
#  u'caribbean island': u'Caribbean Island',
#  u'girl friend': u'Girl Friend',
#  u'swing vote': u'Swing Vote',
#  u'john doe': u'John Doe',
#  u'early riser': u'Early Riser',
#  u'tai dam': u'Tai Dam',
#  u'assemblies of god': u'Assemblies of God',
#  u'nabataean kingdom': u'Nabataean Kingdom',
#  u'hunt v. cromartie': u'Hunt v. Cromartie',
#  u'home improvement': u'Home Improvement',
#  u'human cannonball': u'Human Cannonball',
#  u'havana biennial': u'Havana Biennial',
#  u'romer v. evans': u'Romer v. Evans',
#  u'soft shoes': u'Soft Shoes',
#  u'winter wheat': u'Winter Wheat',
#  u'anglican communion': u'Anglican Communion',
#  u'saint cyril': u'Saint Cyril',
#  u'black note': u'Black Note',
#  u'security studies': u'Security Studies',
#  u'palestine authority': u'Palestine Authority',
#  u'bureau of customs': u'Bureau of Customs',
#  u'pharaoh of egypt': u'Pharaoh of Egypt',
#  u'baltic state': u'Baltic State',
#  u'gilbert and sullivan': u'Gilbert and Sullivan',
#  u'whig party': u'Whig Party',
#  u'fast of esther': u'Fast of Esther',
#  u'hale telescope': u'Hale Telescope',
#  u'urofsky v. gilmore': u'Urofsky v. Gilmore',
#  u'natural causes': u'Natural Causes',
#  u'opening ceremony': u'Opening Ceremony',
#  u'municipal police': u'Municipal Police',
#  u'holy roller': u'Holy Roller',
#  u'coptic church': u'Coptic Church',
#  u'club foot': u'Club Foot',
#  u'diamond v. chakrabarty': u'Diamond v. Chakrabarty',
#  u'roman catholicism': u'Roman Catholicism',
#  u'goss v. lopez': u'Goss v. Lopez',
#  u'garam masala': u'Garam Masala',
#  u'mediterranean sea': u'Mediterranean Sea',
#  u'peace church': u'Peace Church',
#  u'high island': u'High Island',
#  u'mashed potatoes': u'Mashed Potatoes',
#  u'ponce de leon': u'Ponce de Leon',
#  u'wallace v. jaffree': u'Wallace v. Jaffree',
#  u'storm troops': u'Storm Troops',
#  u'financial services': u'Financial Services',
#  u'computer chess': u'Computer Chess',
#  u'crowell v. benson': u'Crowell v. Benson',
#  u'cathedral school': u'Cathedral School',
#  u'cancer research': u'Cancer Research',
#  u'old irish': u'Old Irish',
#  u'central line': u'Central Line',
#  u'jewelry box': u'Jewelry Box',
#  u'michaelmas term': u'Michaelmas Term',
#  u'river island': u'River Island',
#  u'new mexican': u'New Mexican',
#  u'hosty v. carter': u'Hosty v. Carter',
#  u'red indian': u'Red Indian',
#  u'sky blue': u'Sky Blue',
#  u'croix de guerre': u'Croix de Guerre',
#  u'middle high german': u'Middle High German',
#  u'gilmore v. gonzales': u'Gilmore v. Gonzales',
#  u'player one': u'Player One',
#  u'federal reserve board': u'Federal Reserve Board',
#  u'stewart v. abend': u'Stewart v. Abend',
#  u'bellotti v. baird': u'Bellotti v. Baird',
#  u'fly fishing': u'Fly Fishing',
#  u'round church': u'Round Church',
#  u'san miguel': u'San Miguel',
#  u'new norwegian': u'New Norwegian',
#  u'nicene creed': u'Nicene Creed',
#  u'paschal lamb': u'Paschal Lamb',
#  u'bronze star medal': u'Bronze Star Medal',
#  u'scottish highlander': u'Scottish Highlander',
#  u'bush v. gore': u'Bush v. Gore',
#  u'the convention': u'The Convention',
#  u'mueller v. allen': u'Mueller v. Allen',
#  u'the visit': u'The Visit',
#  u'guerrilla warfare': u'Guerrilla Warfare',
#  u'pennsylvania dutch': u'Pennsylvania Dutch',
#  u'wu jinglian': u'Wu Jinglian',
#  u'unconditional surrender': u'Unconditional Surrender',
#  u'box set': u'Box Set',
#  u'queen of england': u'Queen of England',
#  u'union party': u'Union Party',
#  u'blood bath': u'Blood Bath',
#  u'configuration management': u'Configuration Management',
#  u'submarine base': u'Submarine Base',
#  u'liu ye': u'Liu Ye',
#  u'eternal triangle': u'Eternal Triangle',
#  u'texas independence day': u'Texas Independence Day',
#  u'distinguished service order': u'Distinguished Service Order',
#  u'rummel v. estelle': u'Rummel v. Estelle',
#  u'stogner v. california': u'Stogner v. California',
#  u'atkins v. virginia': u'Atkins v. Virginia',
#  u'escape clause': u'Escape Clause',
#  u'canadian french': u'Canadian French',
#  u'black irish': u'Black Irish',
#  u'hostage crisis': u'Hostage Crisis',
#  u'lord of misrule': u'Lord of Misrule',
#  u'medicine wheel': u'Medicine Wheel',
#  u'osamu watanabe': u'Osamu Watanabe',
#  u'the horde': u'The Horde',
#  u'wang xiaobo': u'Wang Xiaobo',
#  u'thematic apperception test': u'Thematic Apperception Test',
#  u'iron age': u'Iron Age',
#  u'skinner v. oklahoma': u'Skinner v. Oklahoma',
#  u'central warehouse': u'Central Warehouse',
#  u'fountain of youth': u'Fountain of Youth',
#  u'happy christmas': u'Happy Christmas',
#  u'agriculture secretary': u'Agriculture Secretary',
#  u'the whale': u'The Whale',
#  u'pennoyer v. neff': u'Pennoyer v. Neff',
#  u'rhodes scholarship': u'Rhodes Scholarship',
#  u'national assembly': u'National Assembly',
#  u'first of may': u'First of May',
#  u'vicar of christ': u'Vicar of Christ',
#  u'karol bagh': u'Karol Bagh',
#  u'education bureau': u'Education Bureau',
#  u'language arts': u'Language Arts',
#  u'loving v. virginia': u'Loving v. Virginia',
#  u'barefoot v. estelle': u'Barefoot v. Estelle',
#  u'dead zone': u'Dead Zone',
#  u'space flight': u'Space Flight',
#  u'smart casual': u'Smart Casual',
#  u'stamp act': u'Stamp Act',
#  u'liberation day': u'Liberation Day',
#  u'liu qi': u'Liu Qi',
#  u'drake equation': u'Drake Equation',
#  u'old testament': u'Old Testament',
#  u'populist party': u'Populist Party',
#  u'miller v. johnson': u'Miller v. Johnson',
#  u'christmas ball': u'Christmas Ball',
#  u'street people': u'Street People',
#  u'south korean': u'South Korean',
#  u'cyber rights': u'Cyber Rights',
#  u'moore street': u'Moore Street',
#  u'family values': u'Family Values',
#  u'free soil party': u'Free Soil Party',
#  u'fabian society': u'Fabian Society',
#  u'guest house': u'Guest House',
#  u'algebraic geometry': u'Algebraic Geometry',
#  u'abashiri prison': u'Abashiri Prison',
#  u'no limit': u'No Limit',
#  u'james bond': u'James Bond',
#  u'ancient india': u'Ancient India',
#  u'secretary of commerce': u'Secretary of Commerce',
#  u'the suit': u'The Suit',
#  u'united nations': u'United Nations',
#  u'underground railway': u'Underground Railway',
#  u'stromberg v. california': u'Stromberg v. California',
#  u'blakely v. washington': u'Blakely v. Washington',
#  u'gonzales v. raich': u'Gonzales v. Raich',
#  u'environmental pollution': u'Environmental Pollution',
#  u'shiite muslim': u'Shiite Muslim',
#  u'civil lines': u'Civil Lines',
#  u'lost property': u'Lost Property',
#  u'rear mirror': u'Rear Mirror',
#  u'holy communion': u'Holy Communion',
#  u'special olympics': u'Special Olympics',
#  u'brian wong': u'Brian Wong',
#  u'progressive party': u'Progressive Party',
#  u'the storm': u'The Storm',
#  u'council of vienne': u'Council of Vienne',
#  u'another world': u'Another World',
#  u'delhaize group': u'Delhaize Group',
#  u'greek church': u'Greek Church',
#  u'john sewell': u'John Sewell',
#  u'north america': u'North America',
#  u'black metal': u'Black Metal',
#  u'peter pan': u'Peter Pan',
#  u'fletcher v. peck': u'Fletcher v. Peck',
#  u'olympian games': u'Olympian Games',
#  u'nessun dorma': u'Nessun Dorma',
#  u'labor notes': u'Labor Notes',
#  u'uncanny valley': u'Uncanny Valley',
#  u'congregational church': u'Congregational Church',
#  u'green left': u'Green Left',
#  u'street party': u'Street Party',
#  u'urban art': u'Urban Art',
#  u'michaelmas day': u'Michaelmas Day',
#  u'eastern philosophy': u'Eastern Philosophy',
#  u'masahiro morioka': u'Masahiro Morioka',
#  u'the list': u'The List',
#  u'trusteeship council': u'Trusteeship Council',
#  u'prenuptial agreement': u'Prenuptial Agreement',
#  u'modern girl': u'Modern Girl',
#  u'braunfeld v. brown': u'Braunfeld v. Brown',
#  u'harmelin v. michigan': u'Harmelin v. Michigan',
#  u'li yi': u'Li Yi',
#  u'american literature': u'American Literature',
#  u'national geospatial-intelligence agency': u'National Geospatial-Intelligence Agency',
#  u'arab league': u'Arab League',
#  u'silver lake': u'Silver Lake',
#  u'inner light': u'Inner Light',
#  u'dalcroze eurhythmics': u'Dalcroze Eurhythmics',
#  u'texas v. white': u'Texas v. White',
#  u'only love': u'Only Love',
#  u'blue bird': u'Blue Bird',
#  u'plum blossom': u'Plum Blossom',
#  u'patent office': u'Patent Office',
#  u'scottish lowlands': u'Scottish Lowlands',
#  u'european economic community': u'European Economic Community',
#  u'prix goncourt': u'Prix Goncourt',
#  u'el nino': u'El Nino',
#  u'nestorian church': u'Nestorian Church',
#  u'little office': u'Little Office',
#  u'grand national': u'Grand National',
#  u'hip hop': u'Hip Hop',
#  u'body heat': u'Body Heat',
#  u'energy secretary': u'Energy Secretary',
#  u'occupational medicine': u'Occupational Medicine',
#  u'spy ship': u'Spy Ship',
#  u'victoria park': u'Victoria Park',
#  u'death metal': u'Death Metal',
#  u'nguyen v. ins': u'Nguyen v. Ins',
#  u'zhao jing': u'Zhao Jing',
#  u'roman baths': u'Roman Baths',
#  u'santa ana': u'Santa Ana',
#  u'el colorado': u'El Colorado',
#  u'foreign body': u'Foreign Body',
#  u'head chef': u'Head Chef',
#  u'construction site': u'Construction Site',
#  u'mickey finn': u'Mickey Finn',
#  u'american party': u'American Party',
#  u'armenian church': u'Armenian Church',
#  u'lorry driver': u'Lorry Driver',
#  u'science magazine': u'Science Magazine',
#  u'web developer': u'Web Developer',
#  u'hill v. mcdonough': u'Hill v. Mcdonough',
#  u'silent comedy': u'Silent Comedy',
#  u'chicago marathon': u'Chicago Marathon',
#  u'li ming': u'Li Ming',
#  u'charles townes': u'Charles Townes',
#  u'mrs. robinson': u'Mrs. Robinson',
#  u'white dragon': u'White Dragon',
#  u'johnny reb': u'Johnny Reb',
#  u'ziegfeld follies': u'Ziegfeld Follies',
#  u'john bull': u'John Bull',
#  u'metro station': u'Metro Station',
#  u'star chamber': u'Star Chamber',
#  u'mikheil saakashvili': u'Mikheil Saakashvili',
#  u'nixon v. fitzgerald': u'Nixon v. Fitzgerald',
#  u'whit monday': u'Whit Monday',
#  u'dark nebula': u'Dark Nebula',
#  u'john terry': u'John Terry',
#  u'book of psalms': u'Book of Psalms',
#  u'madagascar plan': u'Madagascar Plan',
#  u'church father': u'Church Father',
#  u'transfiguration of jesus': u'Transfiguration of Jesus',
#  u'east coast': u'East Coast',
#  u'military medicine': u'Military Medicine',
#  u'liu bo': u'Liu Bo',
#  u'drug enforcement administration': u'Drug Enforcement Administration',
#  u'sinfonia concertante': u'Sinfonia Concertante',
#  u'plains indian': u'Plains Indian',
#  u'witching hour': u'Witching Hour',
#  u'criminal code': u'Criminal Code',
#  u'ancient greek': u'Ancient Greek',
#  u'scorched earth': u'Scorched Earth',
#  u'old high german': u'Old High German',
#  u'anglican catholic': u'Anglican Catholic',
#  u'ancient rome': u'Ancient Rome',
#  u'rock festival': u'Rock Festival',
#  u'environmental protection agency': u'Environmental Protection Agency',
#  u'pythian games': u'Pythian Games',
#  u'la paz': u'La Paz',
#  u'car wash': u'Car Wash',
#  u'tammany society': u'Tammany Society',
#  u'winston v. lee': u'Winston v. Lee',
#  u'lum v. rice': u'Lum v. Rice',
#  u'tennessee v. garner': u'Tennessee v. Garner',
#  u'modern greek': u'Modern Greek',
#  u'four square': u'Four Square',
#  u'arbor day': u'Arbor Day',
#  u'three years': u'Three Years',
#  u'foreign secretary': u'Foreign Secretary',
#  u'feast of tabernacles': u'Feast of Tabernacles',
#  u'st bernard': u'St Bernard',
#  u'vila nova': u'Vila Nova',
#  u'crazy glue': u'Crazy Glue',
#  u'conservative jew': u'Conservative Jew',
#  u'black hand': u'Black Hand',
#  u'woo woo': u'Woo Woo',
#  u'grote markt': u'Grote Markt',
#  u'child actor': u'Child Actor',
#  u'best of': u'Best Of',
#  u'soft rock': u'Soft Rock',
#  u'hall house': u'Hall House',
#  u'hare krishna': u'Hare Krishna',
#  u'world ocean': u'World Ocean',
#  u'the o2': u'The O2',
#  u'action research': u'Action Research',
#  u'lord chancellor': u'Lord Chancellor',
#  u'harpsichord concerto': u'Harpsichord Concerto',
#  u'special branch': u'Special Branch',
#  u'united states army': u'United States Army',
#  u'shaw v. reno': u'Shaw v. Reno',
#  u'yang bin': u'Yang Bin',
#  u'el charco': u'El Charco',
#  u'first vatican council': u'First Vatican Council',
#  u'hanseatic league': u'Hanseatic League',
#  u'department of defense': u'Department of Defense',
#  u'stanford v. kentucky': u'Stanford v. Kentucky',
#  u'brown v. mississippi': u'Brown v. Mississippi',
#  u'midnight movie': u'Midnight Movie',
#  u'north coast': u'North Coast',
#  u'no frills': u'No Frills',
#  u'happy holidays': u'Happy Holidays',
#  u'mclean v. arkansas': u'Mclean v. Arkansas',
#  u'united states congress': u'United States Congress',
#  u'coming out': u'Coming Out',
#  u'society of friends': u'Society of Friends',
#  u'rostker v. goldberg': u'Rostker v. Goldberg',
#  u'kansas v. colorado': u'Kansas v. Colorado',
#  u'divine retribution': u'Divine Retribution',
#  u'liu xin': u'Liu Xin',
#  u'blessed trinity': u'Blessed Trinity',
#  u'smith v. allwright': u'Smith v. Allwright',
#  u'navy secretary': u'Navy Secretary',
#  u'the raiders': u'The Raiders',
#  u'la fleche': u'La Fleche',
#  u'maryland senate': u'Maryland Senate',
#  u'browder v. gayle': u'Browder v. Gayle',
#  u'official opposition': u'Official Opposition',
#  u'free state': u'Free State',
#  u'mccleskey v. kemp': u'Mccleskey v. Kemp',
#  u'ghost story': u'Ghost Story',
#  u'logistics management': u'Logistics Management',
#  u'haig v. agee': u'Haig v. Agee',
#  u'mandarin chinese': u'Mandarin Chinese',
#  u'illinois v. gates': u'Illinois v. Gates',
#  u'project oxygen': u'Project Oxygen',
#  u'troxel v. granville': u'Troxel v. Granville',
#  u'extended play': u'Extended Play',
#  u'high five': u'High Five',
#  u'federal communications commission': u'Federal Communications Commission',
#  u'james wood': u'James Wood',
#  u'greek catholic': u'Greek Catholic',
#  u'old bailey': u'Old Bailey',
#  u'pest house': u'Pest House',
#  u'vacco v. quill': u'Vacco v. Quill',
#  u'lemon v. kurtzman': u'Lemon v. Kurtzman',
#  u'muslim ummah': u'Muslim Ummah',
#  u'john furphy': u'John Furphy',
#  u'cavalry division': u'Cavalry Division',
#  u'texas v. johnson': u'Texas v. Johnson',
#  u'karma yoga': u'Karma Yoga',
#  u'fullilove v. klutznick': u'Fullilove v. Klutznick',
#  u'ashkenazi jews': u'Ashkenazi Jews',
#  u'biblical aramaic': u'Biblical Aramaic',
#  u'pernod ricard': u'Pernod Ricard',
#  u'prince albert': u'Prince Albert',
#  u'nemean games': u'Nemean Games',
#  u'marsh v. chambers': u'Marsh v. Chambers',
#  u'scandinavian design': u'Scandinavian Design',
#  u'doing business as': u'Doing Business As',
#  u'british labour party': u'British Labour Party',
#  u'survival knife': u'Survival Knife',
#  u'four quartets': u'Four Quartets',
#  u'davis v. bandemer': u'Davis v. Bandemer',
#  u'united front': u'United Front',
#  u'gratz v. bollinger': u'Gratz v. Bollinger',
#  u'living history': u'Living History',
#  u'worcester v. georgia': u'Worcester v. Georgia',
#  u'miller v. california': u'Miller v. California',
#  u'continental army': u'Continental Army',
#  u'angel wings': u'Angel Wings',
#  u'feast of booths': u'Feast of Booths',
#  u"johnson v. m'intosh": u"Johnson v. M'Intosh",
#  u'paper airplane': u'Paper Airplane',
#  u'moore v. dempsey': u'Moore v. Dempsey',
#  u'fourth of july': u'Fourth of July',
#  u'south sea islands': u'South Sea Islands',
#  u'wesberry v. sanders': u'Wesberry v. Sanders',
#  u'don juan': u'Don Juan',
#  u'human trafficking': u'Human Trafficking',
#  u'the brotherhood': u'The Brotherhood',
#  u'naval ensign': u'Naval Ensign',
#  u'black american': u'Black American',
#  u'masahiro yamada': u'Masahiro Yamada',
#  u'emmy award': u'Emmy Award',
#  u'uniate church': u'Uniate Church',
#  u'paul v. davis': u'Paul v. Davis',
#  u'adaptive behavior': u'Adaptive Behavior',
#  u'hines v. davidowitz': u'Hines v. Davidowitz',
#  u'evolutionary computation': u'Evolutionary Computation',
#  u'main street': u'Main Street',
#  u'popcorn chicken': u'Popcorn Chicken',
#  u'midsummer day': u'Midsummer Day',
#  u'national democracy': u'National Democracy',
#  u'cherry pie': u'Cherry Pie',
#  u'serkadji prison': u'Serkadji Prison',
#  u'iraqi intelligence service': u'Iraqi Intelligence Service',
#  u'hodgson v. minnesota': u'Hodgson v. Minnesota',
#  u'active citizenship': u'Active Citizenship',
#  u'wickard v. filburn': u'Wickard v. Filburn',
#  u'discus thrower': u'Discus Thrower',
#  u'tar heel': u'Tar Heel',
#  u'christian church': u'Christian Church',
#  u'quinquagesima sunday': u'Quinquagesima Sunday',
#  u'illinois v. rodriguez': u'Illinois v. Rodriguez',
#  u'nobuo matsunaga': u'Nobuo Matsunaga',
#  u'great pyrenees': u'Great Pyrenees',
#  u'chambers v. maroney': u'Chambers v. Maroney',
#  u'west indian': u'West Indian',
#  u'asia minor': u'Asia Minor',
#  u'american indian': u'American Indian',
#  u'as is': u'As Is',
#  u'olympian zeus': u'Olympian Zeus',
#  u'chinese restaurant': u'Chinese Restaurant',
#  u'artificial life': u'Artificial Life',
#  u'cinco de mayo': u'Cinco de Mayo',
#  u'air charter': u'Air Charter',
#  u'snowy owl': u'Snowy Owl',
#  u'r. v. butler': u'R. v. Butler',
#  u'davis cup': u'Davis Cup',
#  u'modern hebrew': u'Modern Hebrew',
#  u'wang jie': u'Wang Jie',
#  u'health policy': u'Health Policy',
#  u'winnebago war': u'Winnebago War',
#  u'hamilton v. regents': u'Hamilton v. Regents',
#  u'rock glacier': u'Rock Glacier',
#  u'tin man': u'Tin Man',
#  u'zhang yan': u'Zhang Yan',
#  u'cunningham v. california': u'Cunningham v. California',
#  u'third lateran council': u'Third Lateran Council',
#  u'day of atonement': u'Day of Atonement',
#  u'psychometric society': u'Psychometric Society',
#  u'distinguished service medal': u'Distinguished Service Medal',
#  u'north atlantic council': u'North Atlantic Council',
#  u'doctor of humanities': u'Doctor of Humanities',
#  u'white tai': u'White Tai',
#  u'george f. kennan': u'George F. Kennan',
#  u'english studies': u'English Studies',
#  u'rough rider': u'Rough Rider',
#  u'post mortem': u'Post Mortem',
#  u'the smurfs': u'The Smurfs',
#  u'hot pursuit': u'Hot Pursuit',
#  u'evelyn hu': u'Evelyn Hu',
#  u'khan market': u'Khan Market',
#  u'black panthers': u'Black Panthers',
#  u'wild west show': u'Wild West Show',
#  u'moving violation': u'Moving Violation',
#  u'wooley v. maynard': u'Wooley v. Maynard',
#  u'u. s. code': u'U. S. Code',
#  u'house of islam': u'House of Islam',
#  u'mujahedeen khalq': u'Mujahedeen Khalq',
#  u'old church slavonic': u'Old Church Slavonic',
#  u'time table': u'Time Table',
#  u'buck v. bell': u'Buck v. Bell',
#  u'trapezium cluster': u'Trapezium Cluster',
#  u'prix de rome': u'Prix de Rome',
#  u'lead vocalist': u'Lead Vocalist',
#  u'virgin birth': u'Virgin Birth',
#  u'bloomsbury group': u'Bloomsbury Group',
#  u'beach volley': u'Beach Volley',
#  u'magic marker': u'Magic Marker',
#  u'middle low german': u'Middle Low German',
#  u'altai republic': u'Altai Republic',
#  u'aguilar v. felton': u'Aguilar v. Felton',
#  u'ithiel town': u'Ithiel Town',
#  u'security council': u'Security Council',
#  u'bartle frere': u'Bartle Frere',
#  u'eysenck personality inventory': u'Eysenck Personality Inventory',
#  u'straight edge': u'Straight Edge',
#  u'high renaissance': u'High Renaissance',
#  u'special edition': u'Special Edition',
#  u'star-spangled banner': u'Star-Spangled Banner',
#  u'slave labour': u'Slave Labour',
#  u'in exile': u'In Exile',
#  u'second lateran council': u'Second Lateran Council',
#  u'high voltage': u'High Voltage',
#  u'i corps': u'I Corps',
#  u'r. v. keegstra': u'R. v. Keegstra',
#  u'umayyad caliphate': u'Umayyad Caliphate',
#  u'sacred grove': u'Sacred Grove',
#  u'feminist studies': u'Feminist Studies',
#  u'south dakotan': u'South Dakotan',
#  u'buchanan v. warley': u'Buchanan v. Warley',
#  u'liu wei': u'Liu Wei',
#  u'jewish orthodoxy': u'Jewish Orthodoxy',
#  u'hurtado v. california': u'Hurtado v. California',
#  u'parliament square': u'Parliament Square',
#  u'gerrards cross': u'Gerrards Cross',
#  u'osama bin laden': u'Osama bin Laden',
#  u'fourth lateran council': u'Fourth Lateran Council',
#  u'word of god': u'Word of God',
#  u'socialist labor party': u'Socialist Labor Party',
#  u'sally lunn': u'Sally Lunn',
#  u'restraining order': u'Restraining Order',
#  u'persea americana': u'Persea Americana',
#  u'guantanamo bay': u'Guantanamo Bay',
#  u'mill race': u'Mill Race',
#  u'the blind': u'The Blind',
#  u'doctor of science': u'Doctor of Science',
#  u'green flag': u'Green Flag',
#  u'secretary of energy': u'Secretary of Energy',
#  u'sun city': u'Sun City',
#  u'johnson v. zerbst': u'Johnson v. Zerbst',
#  u'national emblem': u'National Emblem',
#  u'master of architecture': u'Master of Architecture',
#  u'black panther': u'Black Panther',
#  u'trojan horse': u'Trojan Horse',
#  u'clinical chemistry': u'Clinical Chemistry',
#  u'animal rights': u'Animal Rights',
#  u'christian science': u'Christian Science',
#  u'orthodox church': u'Orthodox Church',
#  u'kon tiki': u'Kon Tiki',
#  u'the singles': u'The Singles',
#  u'vatican council': u'Vatican Council',
#  u'candlemas day': u'Candlemas Day',
#  u'moon landing': u'Moon Landing',
#  u'spring green': u'Spring Green',
#  u'reality show': u'Reality Show',
#  u'falling sickness': u'Falling Sickness',
#  u'commonwealth of nations': u'Commonwealth of Nations',
#  u'grand prix': u'Grand Prix',
#  u'rumsfeld v. padilla': u'Rumsfeld v. Padilla',
#  u'lajpat nagar': u'Lajpat Nagar',
#  u'survival skills': u'Survival Skills',
#  u'younger brother': u'Younger Brother',
#  u'herrera v. collins': u'Herrera v. Collins',
#  u'season finale': u'Season Finale',
#  u'protestant church': u'Protestant Church',
#  u'munich agreement': u'Munich Agreement',
#  u'katzenbach v. mcclung': u'Katzenbach v. Mcclung',
#  u'the crucifixion': u'The Crucifixion',
#  u'secretary of education': u'Secretary of Education',
#  u'faretta v. california': u'Faretta v. California',
#  u'oak leaf cluster': u'Oak Leaf Cluster',
#  u'prigg v. pennsylvania': u'Prigg v. Pennsylvania',
#  u'defense logistics agency': u'Defense Logistics Agency',
#  u'kansas v. crane': u'Kansas v. Crane',
#  u'prairie avenue': u'Prairie Avenue',
#  u'distinguished flying cross': u'Distinguished Flying Cross',
#  u'taxi driver': u'Taxi Driver',
#  u'jeju island': u'Jeju Island',
#  u'business ethics': u'Business Ethics',
#  u'lincolnshire limestone': u'Lincolnshire Limestone',
#  u'holy writ': u'Holy Writ',
#  u'emergency ward': u'Emergency Ward',
#  u'cloud computing': u'Cloud Computing',
#  u'chaos theory': u'Chaos Theory',
#  u'wisconsin badgers': u'Wisconsin Badgers',
#  u'south carolinian': u'South Carolinian',
#  u'little crow': u'Little Crow',
#  u'pond hockey': u'Pond Hockey',
#  u'american studies': u'American Studies',
#  u'kilbourn v. thompson': u'Kilbourn v. Thompson',
#  u'austrian airlines': u'Austrian Airlines',
#  u'russian doll': u'Russian Doll',
#  u'harris v. mcrae': u'Harris v. Mcrae',
#  u'bedtime story': u'Bedtime Story',
#  u'chief constable': u'Chief Constable',
#  u'raymond wong': u'Raymond Wong',
#  u'conservation biology': u'Conservation Biology',
#  u'central force': u'Central Force',
#  u'camera phone': u'Camera Phone',
#  u'east indiaman': u'East Indiaman',
#  u'american way': u'American Way',
#  u'wild turkey': u'Wild Turkey',
#  u'mitchell v. forsyth': u'Mitchell v. Forsyth',
#  u'nonproliferation center': u'Nonproliferation Center',
#  u'luther v. borden': u'Luther v. Borden',
#  u'admission day': u'Admission Day',
#  u'sex museum': u'Sex Museum',
#  u'hassan al-turabi': u'Hassan Al-Turabi',
#  u'michael costa': u'Michael Costa',
#  u'the visitation': u'The Visitation',
#  u'capitol records': u'Capitol Records',
#  u'temple israel': u'Temple Israel',
#  u'evangelical church': u'Evangelical Church',
#  u'creative nonfiction': u'Creative Nonfiction',
#  u'stanley v. georgia': u'Stanley v. Georgia',
#  u'constitutional court': u'Constitutional Court',
#  u'open access': u'Open Access',
#  u'wilson v. arkansas': u'Wilson v. Arkansas',
#  u'illinois v. lidster': u'Illinois v. Lidster',
#  u'net worth': u'Net Worth',
#  u'inauguration day': u'Inauguration Day',
#  u'middle man': u'Middle Man',
#  u'five nations': u'Five Nations',
#  u'german nazi': u'German Nazi',
#  u'russian orthodox church': u'Russian Orthodox Church',
#  u'cultural landscape': u'Cultural Landscape',
#  u'little joe': u'Little Joe',
#  u'technology administration': u'Technology Administration',
#  u'bachelor of divinity': u'Bachelor of Divinity',
#  u'komi republic': u'Komi Republic',
#  u'open university': u'Open University',
#  u'tweedledum and tweedledee': u'Tweedledum and Tweedledee',
#  u'incidental findings': u'Incidental Findings',
#  u'security bureau': u'Security Bureau',
#  u'treasury secretary': u'Treasury Secretary',
#  u'saddle point': u'Saddle Point',
#  u'tom thumb': u'Tom Thumb',
#  u'protestant episcopal church': u'Protestant Episcopal Church',
#  u'lutheran church': u'Lutheran Church',
#  u'arnett v. kennedy': u'Arnett v. Kennedy',
#  u'agostini v. felton': u'Agostini v. Felton',
#  u'virgin mary': u'Virgin Mary',
#  u'white russian': u'White Russian',
#  u'semper fidelis': u'Semper Fidelis',
#  u'segway human transporter': u'Segway Human Transporter',
#  u'swain v. alabama': u'Swain v. Alabama',
#  u'melophagus ovinus': u'Melophagus Ovinus',
#  u'air strike': u'Air Strike',
#  u'situation room': u'Situation Room',
#  u'strait jacket': u'Strait Jacket',
#  u'gideon v. wainwright': u'Gideon v. Wainwright',
#  u'english garden': u'English Garden',
#  u'animal behavior': u'Animal Behavior',
#  u'chinook jargon': u'Chinook Jargon',
#  u'estes v. texas': u'Estes v. Texas',
#  u'grutter v. bollinger': u'Grutter v. Bollinger',
#  u'kent v. dulles': u'Kent v. Dulles',
#  u'hans v. louisiana': u'Hans v. Louisiana',
#  u'bachelor of arts': u'Bachelor of Arts',
#  u'art museum': u'Art Museum',
#  u'grief counseling': u'Grief Counseling',
#  u'spy fiction': u'Spy Fiction',
#  u'bachelor apartment': u'Bachelor Apartment',
#  u'district court': u'District Court',
#  u'solemnity of mary': u'Solemnity of Mary',
#  u'panchen lama': u'Panchen Lama',
#  u'easter sunday': u'Easter Sunday',
#  u'film school': u'Film School',
#  u'platonic academy': u'Platonic Academy',
#  u'tommy thompson': u'Tommy Thompson',
#  u'good book': u'Good Book',
#  u'software factory': u'Software Factory',
#  u'sexual healing': u'Sexual Healing',
#  u'science communication': u'Science Communication',
#  u'war veteran': u'War Veteran',
#  u'city museum': u'City Museum',
#  u'mcculloch v. maryland': u'Mcculloch v. Maryland',
#  u'black partridge': u'Black Partridge',
#  u'power engineering': u'Power Engineering',
#  u'tennessee v. lane': u'Tennessee v. Lane',
#  u'riot act': u'Riot Act',
#  u'army men': u'Army Men',
#  u'secretary of agriculture': u'Secretary of Agriculture',
#  u'string trio': u'String Trio',
#  u'scots gaelic': u'Scots Gaelic',
#  u'bachelor of medicine': u'Bachelor of Medicine',
#  u'ford v. wainwright': u'Ford v. Wainwright',
#  u'back together': u'Back Together',
#  u'universal history': u'Universal History',
#  u'ghost ship': u'Ghost Ship',
#  u'cohen v. california': u'Cohen v. California',
#  u'animal science': u'Animal Science',
#  u'valentine day': u'Valentine Day',
#  u'native alaskan': u'Native Alaskan',
#  u'r and b': u'R and B',
#  u'imperial diet': u'Imperial Diet',
#  u'ninth of ab': u'Ninth of Ab',
#  u'chaoulli v. quebec': u'Chaoulli v. Quebec',
#  u'near v. minnesota': u'Near v. Minnesota',
#  u'federal judiciary': u'Federal Judiciary',
#  u'friend zone': u'Friend Zone',
#  u'common market': u'Common Market',
#  u'league of nations': u'League of Nations',
#  u'williams v. rhodes': u'Williams v. Rhodes',
#  u'go fish': u'Go Fish',
#  u'california roll': u'California Roll',
#  u'greenback party': u'Greenback Party',
#  u'stray dog': u'Stray Dog',
#  u'compact space': u'Compact Space',
#  u'signal corps': u'Signal Corps',
#  u'degenerate art': u'Degenerate Art',
#  u'secret santa': u'Secret Santa',
#  u'background music': u'Background Music',
#  u'lockyer v. andrade': u'Lockyer v. Andrade',
#  u'bowers v. hardwick': u'Bowers v. Hardwick',
#  u'zhang jun': u'Zhang Jun',
#  u'palace park': u'Palace Park',
#  u'lethal injection': u'Lethal Injection',
#  u'bumble bee': u'Bumble Bee',
#  u'harris tweed': u'Harris Tweed',
#  u'shia islam': u'Shia Islam',
#  u'niagara parkway': u'Niagara Parkway',
#  u'mae west': u'Mae West',
#  u'poe v. ullman': u'Poe v. Ullman',
#  u'mitchell v. helms': u'Mitchell v. Helms',
#  u'machine learning': u'Machine Learning',
#  u'miranda v. arizona': u'Miranda v. Arizona',
#  u'big rig': u'Big Rig',
#  u'modern art': u'Modern Art',
#  u'light within': u'Light Within',
#  u'playboy bunny': u'Playboy Bunny',
#  u'rhode islander': u'Rhode Islander',
#  u'my brother': u'My Brother',
#  u'white guilt': u'White Guilt',
#  u'sturm und drang': u'Sturm und Drang',
#  u'memphis blues': u'Memphis Blues',
#  u'personal life': u'Personal Life',
#  u'clinical biochemistry': u'Clinical Biochemistry',
#  u'tailgate party': u'Tailgate Party',
#  u'political communication': u'Political Communication',
#  u'mistaken identity': u'Mistaken Identity',
#  u'ableman v. booth': u'Ableman v. Booth',
#  u'west african': u'West African',
#  u'oregon v. mitchell': u'Oregon v. Mitchell',
#  u'south american': u'South American',
#  u'joint chiefs': u'Joint Chiefs',
#  u'separate tables': u'Separate Tables',
#  u'warming up': u'Warming Up',
#  u'british parliament': u'British Parliament',
#  u'regional power': u'Regional Power',
#  u'santee sioux': u'Santee Sioux',
#  u'lady day': u'Lady Day',
#  u'constitutional union party': u'Constitutional Union Party',
#  u'intelligence community': u'Intelligence Community',
#  u'national security council': u'National Security Council',
#  u'british english': u'British English',
#  u'baptist church': u'Baptist Church',
#  u'battle of gettysburg': u'Battle of Gettysburg',
#  u'loud music': u'Loud Music',
#  u'good news': u'Good News',
#  u'water board': u'Water Board',
#  u'schneckloth v. bustamonte': u'Schneckloth v. Bustamonte',
#  u'my bad': u'My Bad',
#  u'freedom square': u'Freedom Square',
#  u'purple heart': u'Purple Heart',
#  u'the tempest': u'The Tempest',
#  u'conspiracy theory': u'Conspiracy Theory',
#  u'morning show': u'Morning Show',
#  u'roman festivals': u'Roman Festivals',
#  u'burnt offering': u'Burnt Offering',
#  u'hepatitis d': u'Hepatitis D',
#  u'energy technology': u'Energy Technology',
#  u'training camp': u'Training Camp',
#  u'student leader': u'Student Leader',
#  u'special needs': u'Special Needs',
#  u'late latin': u'Late Latin',
#  u'salvation army': u'Salvation Army',
#  u'international finance corporation': u'International Finance Corporation',
#  u'premium bond': u'Premium Bond',
#  u'social research': u'Social Research',
#  u'northern spy': u'Northern Spy',
#  u'american baptist convention': u'American Baptist Convention',
#  u'roller derby': u'Roller Derby',
#  u'rosh hashanah': u'Rosh Hashanah',
#  u'reid v. covert': u'Reid v. Covert',
#  u'the garden': u'The Garden',
#  u'foucha v. louisiana': u'Foucha v. Louisiana',
#  u'crock pot': u'Crock Pot',
#  u'edward grey': u'Edward Grey',
#  u'bolling v. sharpe': u'Bolling v. Sharpe',
#  u'steel valley': u'Steel Valley',
#  u'statistical commission': u'Statistical Commission',
#  u'green room': u'Green Room',
#  u'bluegrass region': u'Bluegrass Region',
#  u'modern paganism': u'Modern Paganism',
#  u'missouri v. holland': u'Missouri v. Holland',
#  u'san pablo': u'San Pablo',
#  u'shah of iran': u'Shah of Iran',
#  u'fight song': u'Fight Song',
#  u'precious memories': u'Precious Memories',
#  u'science park': u'Science Park',
#  u'frisby v. schultz': u'Frisby v. Schultz',
#  u'declaration of independence': u'Declaration of Independence',
#  u'blue line': u'Blue Line',
#  u'prince of wales': u'Prince of Wales',
#  u'attendance allowance': u'Attendance Allowance',
#  u'mechanized infantry': u'Mechanized Infantry',
#  u'tall story': u'Tall Story',
#  u'cherry blossom': u'Cherry Blossom',
#  u'big dipper': u'Big Dipper',
#  u'lewis v. harris': u'Lewis v. Harris',
#  u'basket maker': u'Basket Maker',
#  u'san antone': u'San Antone',
#  u'chen yi': u'Chen Yi',
#  u'frank v. maryland': u'Frank v. Maryland',
#  u'baby teeth': u'Baby Teeth',
#  u'wolf v. colorado': u'Wolf v. Colorado',
#  u'ember day': u'Ember Day',
#  u'wiggins v. smith': u'Wiggins v. Smith',
#  ...}

# %%
# Idea to set lower-cased lexicalisation token attributes to 
# the title case if that distribution likelihood is higher
# note will not work in call cases:
# sue will be more probably than Sue because "sue" refers to the verb
# rather than to the girl's name

probs={w.orth:w.prob for w in nlp.vocab}
usually_titled = [w for w in nlp.vocab if (w.is_title or w.is_upper) and probs.get(w.lower, -10000) < probs.get(w.orth, -10000)]

# %%
nlp.vocab.strings['sue'] # 15556805105345623310L
nlp.vocab.strings['Sue'] # 6419625049723015959L
print 'hurricane' in[w.lower_ for w in usually_titled]
nlp.vocab[nlp.vocab.strings['grappa']].prob
# Out:
# False
# -17.643484115600586

# %%
for token in nlp(u'My favourite_TV program is The Simpsons.'):
    print token.text, token.lemma_, token.pos_, token.head, token.dep_
# Out:
# My -PRON- ADJ program poss
# favourite_TV favourite_tv NOUN program compound
# program program NOUN is nsubj
# is be VERB is ROOT
# The the DET Simpsons det
# Simpsons simpsons PROPN is attr
# . . PUNCT is punct
